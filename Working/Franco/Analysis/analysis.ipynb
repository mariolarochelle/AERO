# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20, 10)
plt.style.use('ggplot')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
#df = pd.read_csv('001082__meas_2017.10.03-2018.01.23.txt_data_cleaned.csv', index_col=0)
df = pd.read_csv('ech1 18092018.txt_data_cleaned.csv', index_col=0)

# %%
df.head()
# Out:
#      Date & Time Stamp  CH1Avg  CH1SD  CH1Max  CH1Min  CH2Avg  CH2SD  CH2Max  \
# 0  2017-09-11 00:00:00    11.8    0.5    13.0    10.7    12.3    0.8    13.7
# 1  2017-09-11 00:10:00    11.0    1.0    12.6     8.8    12.1    0.9    13.7
# 2  2017-09-11 00:20:00     9.4    0.7    11.4     8.4     9.8    1.1    13.4
# 3  2017-09-11 00:30:00     9.3    0.7    12.2     8.0     9.9    1.2    13.7
# 4  2017-09-11 00:40:00     9.6    0.8    12.6     8.4    12.2    1.0    14.1
#
#    CH2Min  CH3Avg  CH3SD  CH3Max  CH3Min  CH4Avg  CH4SD  CH4Max  CH4Min  \
# 0    10.7     9.3    0.7    11.3     7.5     0.3    0.0     0.3     0.3
# 1     9.1     9.5    0.7    12.1     8.2     0.3    0.0     0.3     0.3
# 2     8.0    12.8    1.1    14.0     9.0     0.3    0.0     0.3     0.3
# 3     8.0    12.7    0.4    13.6    11.3     0.3    0.0     0.3     0.3
# 4     8.8    12.2    0.4    12.8    10.9     0.3    0.0     0.3     0.3
#
# ...

# %%
columns_avg = df.columns[['Avg' in x for x in df.columns]]

ch = ['CH1', 'CH2', 'CH3', 'CH13', 'CH14']

matches = ['Date & Time Stamp']
for c in ch:
    #matches.append(c + 'Avg')
    #matches.append(c + 'SD')
    matches.append(c + 'Max')
    matches.append(c + 'Min')

#columns_ch1 = df[[w for w in ch1_matches if w in df.columns]].columns

df_type_1 = df.loc[:, matches]

# %%
df_type_1[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test[0:191].plot()

# %%
df_test['new_col'] = round(df_test['CH4Avg'].diff(periods=1) + df_test['CH4SD'].diff(periods=1) + df_test['CH4Max'].diff(periods=1) + df_test['CH4Min'].diff(periods=1), 5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Program Files (x86)\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CH4Avg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-06aab57371a3> in <module>
# ...

# %%
df_test['new_col2'] = [True if x == 0 else False for x in df_test['new_col']]

# %%
df_test[df_test['new_col2'] == True][:10]
# Out:
#       Date & Time Stamp  CH3Avg  CH3SD  CH3Max  CH3Min  new_col  new_col2
# 34  2017-09-11 05:40:00     7.8    0.6     9.4     6.7      0.0      True
# 53  2017-09-11 08:50:00     9.8    0.9    11.7     7.5      0.0      True
# 69  2017-09-11 11:30:00     0.2    0.0     0.2     0.2      0.0      True
# 70  2017-09-11 11:40:00     0.2    0.0     0.2     0.2      0.0      True
# 71  2017-09-11 11:50:00     0.2    0.0     0.2     0.2      0.0      True
# 72  2017-09-11 12:00:00     0.2    0.0     0.2     0.2      0.0      True
# 73  2017-09-11 12:10:00     0.2    0.0     0.2     0.2      0.0      True
# 74  2017-09-11 12:20:00     0.2    0.0     0.2     0.2      0.0      True
# 75  2017-09-11 12:30:00     0.2    0.0     0.2     0.2      0.0      True
# 76  2017-09-11 12:40:00     0.2    0.0     0.2     0.2      0.0      True

# %%
df_test[64:91]
# Out:
#       Date & Time Stamp  CH14Avg  CH14SD  CH14Max  CH14Min
# 64  2017-09-11 10:40:00      8.5     0.9     10.9      6.0
# 65  2017-09-11 10:50:00      8.8     1.1     10.9      6.3
# 66  2017-09-11 11:00:00      8.0     1.1     10.2      5.2
# 67  2017-09-11 11:10:00      2.9     4.0     10.2      0.2
# 68  2017-09-11 11:20:00      0.2     0.0      0.2      0.2
# 69  2017-09-11 11:30:00      0.2     0.0      0.2      0.2
# 70  2017-09-11 11:40:00      0.2     0.0      0.2      0.2
# 71  2017-09-11 11:50:00      0.2     0.0      0.6      0.2
# 72  2017-09-11 12:00:00      0.2     0.0      0.2      0.2
# 73  2017-09-11 12:10:00      0.2     0.0      0.2      0.2
# 74  2017-09-11 12:20:00      0.2     0.0      0.2      0.2
# 75  2017-09-11 12:30:00      0.2     0.0      0.2      0.2
# 76  2017-09-11 12:40:00      0.2     0.0      0.2      0.2
# 77  2017-09-11 12:50:00      0.2     0.0      0.2      0.2
# 78  2017-09-11 13:00:00      0.2     0.0      0.2      0.2
# ...

# %%
df_test['new_col3'] = round(df_test['CH1Min'].rolling(2).mean(), 4)

# %%
df_test['new_col3'][:90].plot()

# %%
df_test['CH2Max'].plot()

# %%
ch_type_3 = ['CH7', 'CH8']

matches_type_3 = ['Date & Time Stamp']
for c in ch_type_3:
    matches_type_3.append(c + 'Avg')
    matches_type_3.append(c + 'SD')
    matches_type_3.append(c + 'Max')
    matches_type_3.append(c + 'Min')

#columns_ch1 = df[[w for w in ch1_matches if w in df.columns]].columns

df_type_3 = df.loc[:, matches_type_3]

df_type_3[0:191].plot()

# %%
ch_type_4 = ['CH9', 'CH10']

matches_type_4 = ['Date & Time Stamp']
for c in ch_type_4:
    matches_type_4.append(c + 'Avg')
    matches_type_4.append(c + 'SD')
    matches_type_4.append(c + 'Max')
    matches_type_4.append(c + 'Min')

#columns_ch1 = df[[w for w in ch1_matches if w in df.columns]].columns

df_type_4 = df.loc[:, matches_type_4]

df_type_4[0:191].plot()

# %%
ch_type_V = ['CH12']

matches_type_V = ['Date & Time Stamp']
for c in ch_type_V:
    matches_type_V.append(c + 'Avg')
    matches_type_V.append(c + 'SD')
    matches_type_V.append(c + 'Max')
    matches_type_V.append(c + 'Min')

#columns_ch1 = df[[w for w in ch1_matches if w in df.columns]].columns

df_type_V = df.loc[:, matches_type_V]

df_type_V[0:191].plot()
